# %% [markdown]
# # Part 1: Visualize Dataset
#
# The dataset is a collection of temperature recording over 5 years at a weather station in Germany

# %%
# %matplotlib inline
import datasetAnalysis

datasetAnalysis.main()
# Out:
# Total duration for reading 26208: 0.178
# Total duration for reading 26496: 0.177
# Total duration for reading 26064: 0.179
# Total duration for reading 26496: 0.179
# Total duration for reading 26064: 0.177
# Total duration for reading 26446: 0.175
# Total duration for reading 25304: 0.167
# Total duration for reading 26385: 0.178
# Total duration for reading 26189: 0.172
# Total duration for reading 26496: 0.180
#
# Training set - std: 8.564415861456341, mean: 9.122690303852345, shape: (157774,)
# Storing the mean and std of training set in ./data/train/stat.pickle
#
# Validation set - std: 8.234148948577337, mean: 9.96473563040492, shape: (51689,)
# Storing the mean and std of validation set in ./data/validate/stat.pickle
#
# Test set - std: 8.763926933351236, mean: 9.364455727436653, shape: (52685,)
# Storing the mean and std of validation set in ./data/test/stat.pickle
#
# Total duration for plotting: 0.168

# %% [markdown]
# # Part 2: Train a RNN model
