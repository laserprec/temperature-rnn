# %% [markdown]
# # Part 1: Visualize Dataset
#
# The dataset is a collection of temperature recording over 5 years at a [weather station in Germany](https://www.bgc-jena.mpg.de/wetter/)

# %%
# %matplotlib inline
import datasetAnalysis

datasetAnalysis.main()
# Out:
# Training set - std: 8.564415861456341, mean: 9.122690303852345, shape: (157774, 1)
# Storing the mean and std of training set in ./data/train/stat.pickle
#
# Validation set - std: 8.234148948577337, mean: 9.96473563040492, shape: (51689, 1)
# Storing the mean and std of validation set in ./data/validate/stat.pickle
#
# Test set - std: 8.763926933351236, mean: 9.364455727436653, shape: (52685, 1)
# Storing the mean and std of validation set in ./data/test/stat.pickle

# %% [markdown]
# # Part 2: Train a RNN model

# %%
import train

train.main()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# ...
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 1/20
#  - 2s - loss: 0.0783 - val_loss: 0.0436
# Epoch 2/20
#  - 1s - loss: 0.0185 - val_loss: 0.0375
# Epoch 3/20
#  - 1s - loss: 0.0381 - val_loss: 0.0857
# Epoch 4/20
#  - 1s - loss: 0.0370 - val_loss: 0.0314
# Epoch 5/20
#  - 1s - loss: 0.0373 - val_loss: 0.0581
# Epoch 6/20
#  - 1s - loss: 0.0384 - val_loss: 0.0512
# Epoch 7/20
#  - 1s - loss: 0.0343 - val_loss: 0.0216
# Epoch 8/20
#  - 1s - loss: 0.0200 - val_loss: 0.0255
# Epoch 9/20
#  - 1s - loss: 0.0478 - val_loss: 0.0317
# ...

# %% [markdown]
# # Part 3: Prediction

# %% [markdown]
# #### Model has great performance when trained on SMALL sampling rate

# %%
import predict as p

TRAINED_MODEL = './models/working/hid32_lkb144_win128_smpr6_pred1_18-08-09_02-29-57.h5'

trainPred, validatePred, testPred, groundTruth = p.predict(TRAINED_MODEL)
p.plotPrediction(trainPred, validatePred, testPred, groundTruth)
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# ...
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# LOADING model weights from ./models/working/hid32_lkb144_win128_smpr6_pred1_18-08-09_02-29-57.h5
#
# MODEL Parmeters: 32 hiddenNodes, 144 lookBack, 128 windowSize, 6 sampleRate, 1 prediction step
# trainStep: 1085, validationStep: 256, testStep: 264
# Time to make (138880, 1) training predictions: 22.285, training dataset shape (157774, 1)
# Time to make (32768, 1) validation predictions: 5.133, validation dataset shape (51689, 1)
# ...

# %% [markdown]
# ### Model has poorer performance when trained on LARGE sampling rate

# %%
import predict as p

TRAINED_MODEL = './models/hid32_lkb144_win128_smpr128_pred1_18-08-11_16-29-35.h5'

trainPred, validatePred, testPred, groundTruth = p.predict(TRAINED_MODEL)
p.plotPrediction(trainPred, validatePred, testPred, groundTruth)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_2 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# ...
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# LOADING model weights from ./models/hid32_lkb144_win128_smpr128_pred1_18-08-11_16-29-35.h5
#
# MODEL Parmeters: 32 hiddenNodes, 144 lookBack, 128 windowSize, 128 sampleRate, 1 prediction step
# trainStep: 1085, validationStep: 256, testStep: 264
# Time to make (138880, 1) training predictions: 21.877, training dataset shape (157774, 1)
# Time to make (32768, 1) validation predictions: 5.086, validation dataset shape (51689, 1)
# Time to make (33792, 1) test predictions: 5.174, test dataset shape (52685, 1)
# ...
